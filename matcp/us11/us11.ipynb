# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Inquiry.csv', sep=';')

# %%
# Types
# Age Range: Quantitative, Discrete, Ordinal
# Recommendation: Qualitative, Discrete, Nominal
# Visits: Quantitative, Discrete, Nominal

# %%
sns.boxplot(data=df, x='Escalao', y='Visits')
# Out:
# <Axes: xlabel='Escalao', ylabel='Visits'>
